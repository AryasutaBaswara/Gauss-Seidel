# %% [markdown]
# <a href="https://colab.research.google.com/github/AryasutaBaswara/LAB-Scientific-Computing/blob/main/AOL_2_Scientific_Computing_(2702263680_Aryasuta_Baswara).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# Load the production data
production_data = [
    1863, 1614, 2570, 1685, 2101, 1811, 2457, 2171, 2134, 2502, 2358, 2399, 2048, 2523, 2086, 2391, 2150, 2340, 3129, 2277, 2964, 2997, 2747, 2862,
    3405, 2677, 2749, 2755, 2963, 3161, 3623, 2768, 3141, 3439, 3601, 3531, 3477, 3376, 4027, 3175, 3274, 3334, 3964, 3649, 3502, 3688, 3657, 4422,
    4197, 4441, 4736, 4521, 4485, 4644, 5036, 4876, 4789, 4544, 4975, 5211, 4880, 4933, 5079, 5339, 5232, 5520, 5714, 5260, 6110, 5334, 5988, 6235,
    6365, 6266, 6345, 6118, 6497, 6278, 6638, 6590, 6271, 7246, 6584, 6594, 7092, 7326, 7409, 7976, 7959, 8012, 8195, 8008, 8313, 7791, 8368, 8933,
    8756, 8613, 8705, 9098, 8769, 9544, 9050, 9186, 10012, 9685, 9966, 10048, 10244, 10740, 10318, 10393, 10986, 10635, 10731, 11749, 11849, 12123,
    12274, 11666, 11960, 12629, 12915, 13051, 13387, 13309, 13732, 13162, 13644, 13808, 14101, 13992, 15191, 15018, 14917, 15046, 15556, 15893, 16388,
    16782, 16716, 17033, 16896, 17689
]

# Time period (months)
time_period = np.arange(1, len(production_data) + 1)

# Define the exponential model function
def exponential_model(x, a, b):
    return a * np.exp(b * x)

# Fit the exponential model to the data
params, _ = curve_fit(exponential_model, time_period, production_data)

# Extract the parameters
a, b = params

# Define the function to calculate production numerically
def calculate_production_numerically(x):
    return a * np.exp(b * x)

# Define the function to predict when to build a new warehouse
def predict_new_warehouse_construction_time():
    warehouse_capacity = 25000  # Maximum bags per month
    lead_time = 13  # Minimum lead time for construction (in months)
    for month in range(len(production_data)):
        if calculate_production_numerically(month) > warehouse_capacity:
            return month + lead_time

# Output the results
print("1. Exponential Growth Model Parameters:")
print("   Initial Production (a):", a)
print("   Growth Rate (b):", b)
print("\n2. Converted Numerical Model:")
print("   Production at Month 1:", calculate_production_numerically(1))
print("   Production at Month 144:", calculate_production_numerically(144))
print("\n3. Prediction for New Warehouse Construction:")
print("   EGIER should start building a new warehouse in Month:", predict_new_warehouse_construction_time())

# Plot the production data and the fitted trend line
plt.figure(figsize=(10, 6))
plt.plot(time_period, production_data, label='Production Data', color='blue', marker='o')
plt.plot(time_period, exponential_model(time_period, *params), label='Fitted Trend', color='red')
plt.xlabel('Month')
plt.ylabel('Production')
plt.title('Production Trend')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 1. Exponential Growth Model Parameters:
#    Initial Production (a): -7.540278958477207e-15
#    Growth Rate (b): 0.9999999999188695
#
# 2. Converted Numerical Model:
#    Production at Month 1: -2.0496603272677787e-14
#    Production at Month 144: -2.604910475419987e+48
#
# 3. Prediction for New Warehouse Construction:
#    EGIER should start building a new warehouse in Month: None
